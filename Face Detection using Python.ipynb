# %%
pip install cvlib
# Out:
# Requirement already satisfied: cvlib in c:\programdata\anaconda3\lib\site-packages (0.2.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from cvlib) (2.24.0)
# Requirement already satisfied: imutils in c:\programdata\anaconda3\lib\site-packages (from cvlib) (0.5.3)
#
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from cvlib) (1.19.2)
# Requirement already satisfied: progressbar in c:\programdata\anaconda3\lib\site-packages (from cvlib) (2.5)
# Requirement already satisfied: imageio in c:\programdata\anaconda3\lib\site-packages (from cvlib) (2.9.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from cvlib) (8.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->cvlib) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->cvlib) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->cvlib) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->cvlib) (3.0.4)

# %%
# import libraries
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from IPython.display import Image 
Image(filename='couple-4445670_640.jpeg')

# %%
image_path = 'couple-4445670_640.jpeg'
im = cv2.imread(image_path)
plt.imshow(im)
plt.show()

# %%
faces, confidences = cv.detect_face(im)# loop through detected faces and add bounding box
for face in faces:
    (startX,startY) = face[0],face[1]
    (endX,endY) = face[2],face[3]    # draw rectangle over face
    cv2.rectangle(im, (startX,startY), (endX,endY), (0,255,0), 2)# display output        
plt.imshow(im)
plt.show()
